# %%
import requests

url = "https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-intro/minsearch.py"
response = requests.get(url)

with open("minsearch.py", "wb") as file:
    file.write(response.content)

# %%
import pandas as pd
import minsearch

# %%
health_df = pd.read_csv("healthcare_dataset.csv",nrows=500)

# %%
health_df
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 0       Bobby JacksOn   30    Male         B-            Cancer
# 1        LesLie TErRy   62    Male         A+           Obesity
# 2         DaNnY sMitH   76  Female         A-           Obesity
# 3        andrEw waTtS   28  Female         O+          Diabetes
# 4       adrIENNE bEll   43  Female        AB+            Cancer
# ..                ...  ...     ...        ...               ...
# 495     denNIs cLarkE   22  Female        AB+           Obesity
# 496   jeNNiFER spEnCe   65  Female         A+           Obesity
# 497  biLlY fITZGERALd   73  Female         B+            Asthma
# 498     krisTEN JamES   82  Female        AB+      Hypertension
# 499    cAiTLIN bEndEr   32  Female         O-         Arthritis
#
#     Date of Admission              Doctor                      Hospital  \
# 0          2024-01-31       Matthew Smith               Sons and Miller
# 1          2019-08-20     Samantha Davies                       Kim Inc
# 2          2022-09-22    Tiffany Mitchell                      Cook PLC
# 3          2020-11-18         Kevin Wells    Hernandez Rogers and Vang,
# 4          2022-09-19      Kathleen Hanna                   White-White
# ..                ...                 ...                           ...
# 495        2019-09-17          Mark Baker                  Warren-Brown
# 496        2019-05-14        Austin Perry                    Ruiz Group
# 497        2020-05-31  Dr. Mackenzie Bell                Anderson-Brown
# 498        2020-03-27    Kimberly Calhoun                 Hull Sons and
# 499        2019-12-23     Timothy Aguilar  Oliver Mcdonald, and Johnson
#
#     Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Blue Cross    18856.281306          328         Urgent
# 1             Medicare    33643.327287          265      Emergency
# 2                Aetna    27955.096079          205      Emergency
# 3             Medicare    37909.782410          450       Elective
# 4                Aetna    14238.317814          458         Urgent
# ..                 ...             ...          ...            ...
# 495              Cigna     8033.611655          293       Elective
# 496           Medicare     7391.534745          270       Elective
# 497              Aetna    35945.884474          146      Emergency
# 498           Medicare    10780.742008          472      Emergency
# 499              Aetna    28743.003838          493       Elective
#
#     Discharge Date   Medication  Test Results
# 0       2024-02-02  Paracetamol        Normal
# 1       2019-08-26    Ibuprofen  Inconclusive
# 2       2022-10-07      Aspirin        Normal
# 3       2020-12-18    Ibuprofen      Abnormal
# 4       2022-10-09   Penicillin      Abnormal
# ..             ...          ...           ...
# 495     2019-10-01      Lipitor  Inconclusive
# 496     2019-05-20      Aspirin  Inconclusive
# 497     2020-06-28    Ibuprofen  Inconclusive
# 498     2020-04-04    Ibuprofen  Inconclusive
# 499     2019-12-30   Penicillin        Normal
#
# [500 rows x 15 columns]

# %%
health_df.columns = health_df.columns.str.lower().str.replace(' ','_')
# Convert specific columns to strings if needed
health_df['age'] = health_df['age'].astype(str)
health_df['billing_amount'] = health_df['billing_amount'].astype(str)
health_df['room_number'] = health_df['room_number'].astype(str)

# %%
documents = health_df.to_dict(orient='records')

# %%
documents
# Out:
# [{'name': 'Bobby JacksOn',
#   'age': '30',
#   'gender': 'Male',
#   'blood_type': 'B-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2024-01-31',
#   'doctor': 'Matthew Smith',
#   'hospital': 'Sons and Miller',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '18856.281305978155',
#   'room_number': '328',
#   'admission_type': 'Urgent',
#   'discharge_date': '2024-02-02',
#   'medication': 'Paracetamol',
#   'test_results': 'Normal'},
#  {'name': 'LesLie TErRy',
#   'age': '62',
#   'gender': 'Male',
#   'blood_type': 'A+',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2019-08-20',
#   'doctor': 'Samantha Davies',
#   'hospital': 'Kim Inc',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '33643.327286577885',
#   'room_number': '265',
#   'admission_type': 'Emergency',
#   'discharge_date': '2019-08-26',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'DaNnY sMitH',
#   'age': '76',
#   'gender': 'Female',
#   'blood_type': 'A-',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2022-09-22',
#   'doctor': 'Tiffany Mitchell',
#   'hospital': 'Cook PLC',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '27955.096078842456',
#   'room_number': '205',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-10-07',
#   'medication': 'Aspirin',
#   'test_results': 'Normal'},
#  {'name': 'andrEw waTtS',
#   'age': '28',
#   'gender': 'Female',
#   'blood_type': 'O+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2020-11-18',
#   'doctor': 'Kevin Wells',
#   'hospital': 'Hernandez Rogers and Vang,',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '37909.78240987528',
#   'room_number': '450',
#   'admission_type': 'Elective',
#   'discharge_date': '2020-12-18',
#   'medication': 'Ibuprofen',
#   'test_results': 'Abnormal'},
#  {'name': 'adrIENNE bEll',
#   'age': '43',
#   'gender': 'Female',
#   'blood_type': 'AB+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2022-09-19',
#   'doctor': 'Kathleen Hanna',
#   'hospital': 'White-White',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '14238.317813937623',
#   'room_number': '458',
#   'admission_type': 'Urgent',
#   'discharge_date': '2022-10-09',
#   'medication': 'Penicillin',
#   'test_results': 'Abnormal'},
#  {'name': 'EMILY JOHNSOn',
#   'age': '36',
#   'gender': 'Male',
#   'blood_type': 'A+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2023-12-20',
#   'doctor': 'Taylor Newton',
#   'hospital': 'Nunez-Humphrey',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '48145.11095104189',
#   'room_number': '389',
#   'admission_type': 'Urgent',
#   'discharge_date': '2023-12-24',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'edwArD EDWaRDs',
#   'age': '21',
#   'gender': 'Female',
#   'blood_type': 'AB-',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2020-11-03',
#   'doctor': 'Kelly Olson',
#   'hospital': 'Group Middleton',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '19580.87234486093',
#   'room_number': '389',
#   'admission_type': 'Emergency',
#   'discharge_date': '2020-11-15',
#   'medication': 'Paracetamol',
#   'test_results': 'Inconclusive'},
#  {'name': 'CHrisTInA MARtinez',
#   'age': '20',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2021-12-28',
#   'doctor': 'Suzanne Thomas',
#   'hospital': 'Powell Robinson and Valdez,',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '45820.46272159459',
#   'room_number': '277',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-01-07',
#   'medication': 'Paracetamol',
#   'test_results': 'Inconclusive'},
#  {'name': 'JASmINe aGuIlaR',
#   'age': '82',
#   'gender': 'Male',
#   'blood_type': 'AB+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2020-07-01',
#   'doctor': 'Daniel Ferguson',
#   'hospital': 'Sons Rich and',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '50119.222791548505',
#   'room_number': '316',
#   'admission_type': 'Elective',
#   'discharge_date': '2020-07-14',
#   'medication': 'Aspirin',
#   'test_results': 'Abnormal'},
#  {'name': 'ChRISTopher BerG',
#   'age': '58',
#   'gender': 'Female',
#   'blood_type': 'AB-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2021-05-23',
#   'doctor': 'Heather Day',
#   'hospital': 'Padilla-Walker',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '19784.63106221073',
#   'room_number': '249',
#   'admission_type': 'Elective',
#   'discharge_date': '2021-06-22',
#   'medication': 'Paracetamol',
#   'test_results': 'Inconclusive'},
#  {'name': 'mIchElLe daniELs',
#   'age': '72',
#   'gender': 'Male',
#   'blood_type': 'O+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2020-04-19',
#   'doctor': 'John Duncan',
#   'hospital': 'Schaefer-Porter',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '12576.795609050234',
#   'room_number': '394',
#   'admission_type': 'Urgent',
#   'discharge_date': '2020-04-22',
#   'medication': 'Paracetamol',
#   'test_results': 'Normal'},
#  {'name': 'aaRon MARtiNeZ',
#   'age': '38',
#   'gender': 'Female',
#   'blood_type': 'A-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2023-08-13',
#   'doctor': 'Douglas Mayo',
#   'hospital': 'Lyons-Blair',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '7999.586879604188',
#   'room_number': '288',
#   'admission_type': 'Urgent',
#   'discharge_date': '2023-09-05',
#   'medication': 'Lipitor',
#   'test_results': 'Inconclusive'},
#  {'name': 'connOR HANsEn',
#   'age': '75',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2019-12-12',
#   'doctor': 'Kenneth Fletcher',
#   'hospital': 'Powers Miller, and Flores',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '43282.28335770435',
#   'room_number': '134',
#   'admission_type': 'Emergency',
#   'discharge_date': '2019-12-28',
#   'medication': 'Penicillin',
#   'test_results': 'Abnormal'},
#  {'name': 'rObeRt bAuer',
#   'age': '68',
#   'gender': 'Female',
#   'blood_type': 'AB+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2020-05-22',
#   'doctor': 'Theresa Freeman',
#   'hospital': 'Rivera-Gutierrez',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '33207.706633729606',
#   'room_number': '309',
#   'admission_type': 'Urgent',
#   'discharge_date': '2020-06-19',
#   'medication': 'Lipitor',
#   'test_results': 'Normal'},
#  {'name': 'bROOkE brady',
#   'age': '44',
#   'gender': 'Female',
#   'blood_type': 'AB+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2021-10-08',
#   'doctor': 'Roberta Stewart',
#   'hospital': 'Morris-Arellano',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '40701.599227308754',
#   'room_number': '182',
#   'admission_type': 'Urgent',
#   'discharge_date': '2021-10-13',
#   'medication': 'Paracetamol',
#   'test_results': 'Normal'},
#  {'name': 'MS. nAtalIE gAMble',
#   'age': '46',
#   'gender': 'Female',
#   'blood_type': 'AB-',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2023-01-01',
#   'doctor': 'Maria Dougherty',
#   'hospital': 'Cline-Williams',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '12263.357425021362',
#   'room_number': '465',
#   'admission_type': 'Elective',
#   'discharge_date': '2023-01-11',
#   'medication': 'Aspirin',
#   'test_results': 'Inconclusive'},
#  {'name': 'haley perkins',
#   'age': '63',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2020-06-23',
#   'doctor': 'Erica Spencer',
#   'hospital': 'Cervantes-Wells',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '24499.847903736576',
#   'room_number': '114',
#   'admission_type': 'Elective',
#   'discharge_date': '2020-07-14',
#   'medication': 'Paracetamol',
#   'test_results': 'Normal'},
#  {'name': 'mRS. jamiE cAMPBELl',
#   'age': '38',
#   'gender': 'Male',
#   'blood_type': 'AB-',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2020-03-08',
#   'doctor': 'Justin Kim',
#   'hospital': 'Torres, and Harrison Jones',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '17440.465444124675',
#   'room_number': '449',
#   'admission_type': 'Urgent',
#   'discharge_date': '2020-04-02',
#   'medication': 'Paracetamol',
#   'test_results': 'Abnormal'},
#  {'name': 'LuKE BuRgEss',
#   'age': '34',
#   'gender': 'Female',
#   'blood_type': 'A-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2021-03-04',
#   'doctor': 'Justin Moore Jr.',
#   'hospital': 'Houston PLC',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '18843.02301783416',
#   'room_number': '260',
#   'admission_type': 'Elective',
#   'discharge_date': '2021-03-14',
#   'medication': 'Aspirin',
#   'test_results': 'Abnormal'},
#  {'name': 'dANIEL schmIdt',
#   'age': '63',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2022-11-15',
#   'doctor': 'Denise Galloway',
#   'hospital': 'Hammond Ltd',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '23762.203579059587',
#   'room_number': '465',
#   'admission_type': 'Elective',
#   'discharge_date': '2022-11-22',
#   'medication': 'Penicillin',
#   'test_results': 'Normal'},
#  {'name': 'tIMOTHY burNs',
#   'age': '67',
#   'gender': 'Female',
#   'blood_type': 'A-',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2023-06-28',
#   'doctor': 'Krista Smith',
#   'hospital': 'Jones LLC',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '42.5145885533243',
#   'room_number': '115',
#   'admission_type': 'Elective',
#   'discharge_date': '2023-07-02',
#   'medication': 'Aspirin',
#   'test_results': 'Normal'},
#  {'name': 'ChRISToPHEr BRiGhT',
#   'age': '48',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2020-01-21',
#   'doctor': 'Gregory Smith',
#   'hospital': 'Williams-Davis',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '17695.911622343818',
#   'room_number': '295',
#   'admission_type': 'Urgent',
#   'discharge_date': '2020-02-09',
#   'medication': 'Lipitor',
#   'test_results': 'Normal'},
#  {'name': 'KatHRYn StewArt',
#   'age': '58',
#   'gender': 'Female',
#   'blood_type': 'O+',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2022-05-12',
#   'doctor': 'Vanessa Newton',
#   'hospital': 'Clark-Mayo',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '5998.10290819591',
#   'room_number': '327',
#   'admission_type': 'Urgent',
#   'discharge_date': '2022-06-10',
#   'medication': 'Lipitor',
#   'test_results': 'Inconclusive'},
#  {'name': 'dR. EilEEn thomPsoN',
#   'age': '59',
#   'gender': 'Male',
#   'blood_type': 'A+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2021-08-02',
#   'doctor': 'Donna Martinez MD',
#   'hospital': 'and Sons Smith',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '25250.05242821613',
#   'room_number': '119',
#   'admission_type': 'Urgent',
#   'discharge_date': '2021-08-12',
#   'medication': 'Lipitor',
#   'test_results': 'Inconclusive'},
#  {'name': 'PAUl hEndERsOn',
#   'age': '72',
#   'gender': 'Female',
#   'blood_type': 'AB+',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2020-05-15',
#   'doctor': 'Stephanie Kramer',
#   'hospital': 'Wilson Group',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '33211.29541901202',
#   'room_number': '109',
#   'admission_type': 'Emergency',
#   'discharge_date': '2020-06-08',
#   'medication': 'Paracetamol',
#   'test_results': 'Inconclusive'},
#  {'name': 'PeTER fiTzgeRaLd',
#   'age': '73',
#   'gender': 'Male',
#   'blood_type': 'AB+',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2020-05-15',
#   'doctor': 'Angela Contreras',
#   'hospital': 'Garner-Bowman',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '19746.83200760437',
#   'room_number': '162',
#   'admission_type': 'Urgent',
#   'discharge_date': '2020-05-20',
#   'medication': 'Aspirin',
#   'test_results': 'Abnormal'},
#  {'name': 'cathy sMaLl',
#   'age': '51',
#   'gender': 'Female',
#   'blood_type': 'O-',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2023-12-23',
#   'doctor': 'Wendy Glenn',
#   'hospital': 'Brown, and Jones Weaver',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '26786.52955531129',
#   'room_number': '401',
#   'admission_type': 'Elective',
#   'discharge_date': '2024-01-19',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'mr. KenNEth MoORE',
#   'age': '34',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2022-06-21',
#   'doctor': 'James Ellis',
#   'hospital': 'Serrano-Dixon',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '18834.80134117836',
#   'room_number': '157',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-06-30',
#   'medication': 'Lipitor',
#   'test_results': 'Abnormal'},
#  {'name': 'MaRy hUNter',
#   'age': '38',
#   'gender': 'Female',
#   'blood_type': 'O-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2021-01-03',
#   'doctor': 'Jared Bruce Jr.',
#   'hospital': 'Gardner-Miller',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '32643.299353277187',
#   'room_number': '223',
#   'admission_type': 'Emergency',
#   'discharge_date': '2021-01-16',
#   'medication': 'Penicillin',
#   'test_results': 'Normal'},
#  {'name': 'jOSHUA OLiVer',
#   'age': '63',
#   'gender': 'Female',
#   'blood_type': 'B+',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2023-10-03',
#   'doctor': 'Brandy Mitchell',
#   'hospital': 'Guerrero-Boone',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '5767.011053816016',
#   'room_number': '293',
#   'admission_type': 'Elective',
#   'discharge_date': '2023-10-12',
#   'medication': 'Paracetamol',
#   'test_results': 'Abnormal'},
#  {'name': 'ThOMAS MartInEZ',
#   'age': '34',
#   'gender': 'Male',
#   'blood_type': 'B-',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2019-08-18',
#   'doctor': 'Jacob Huynh',
#   'hospital': 'Hart Ltd',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '47909.12880987492',
#   'room_number': '371',
#   'admission_type': 'Urgent',
#   'discharge_date': '2019-09-01',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'JAmES pattERson',
#   'age': '23',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2019-11-03',
#   'doctor': 'Kristina Frazier',
#   'hospital': 'Cruz-Santiago',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '25835.323594688223',
#   'room_number': '108',
#   'admission_type': 'Urgent',
#   'discharge_date': '2019-11-29',
#   'medication': 'Penicillin',
#   'test_results': 'Abnormal'},
#  {'name': 'WilLIAM cOOPEr',
#   'age': '78',
#   'gender': 'Male',
#   'blood_type': 'AB-',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2023-05-18',
#   'doctor': 'John Hartman',
#   'hospital': 'Group Duncan',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '17993.226200015546',
#   'room_number': '245',
#   'admission_type': 'Elective',
#   'discharge_date': '2023-06-15',
#   'medication': 'Penicillin',
#   'test_results': 'Normal'},
#  {'name': 'Erin oRTEga',
#   'age': '43',
#   'gender': 'Male',
#   'blood_type': 'AB-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2023-05-24',
#   'doctor': 'Heather Garcia',
#   'hospital': 'Lopez-Phillips',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '21185.953530394218',
#   'room_number': '494',
#   'admission_type': 'Elective',
#   'discharge_date': '2023-06-03',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'NicOlE RodriGUEz',
#   'age': '30',
#   'gender': 'Female',
#   'blood_type': 'AB+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2020-01-17',
#   'doctor': 'Lynn Young',
#   'hospital': 'Poole Inc',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '8408.94935429195',
#   'room_number': '285',
#   'admission_type': 'Emergency',
#   'discharge_date': '2020-02-10',
#   'medication': 'Lipitor',
#   'test_results': 'Normal'},
#  {'name': 'DAvID AndErSON',
#   'age': '25',
#   'gender': 'Female',
#   'blood_type': 'AB+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2021-01-07',
#   'doctor': 'Emma Allison',
#   'hospital': 'Sons and Cox',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '45453.41854566515',
#   'room_number': '228',
#   'admission_type': 'Elective',
#   'discharge_date': '2021-01-26',
#   'medication': 'Lipitor',
#   'test_results': 'Abnormal'},
#  {'name': 'DEnIse ToRRES',
#   'age': '33',
#   'gender': 'Male',
#   'blood_type': 'AB+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2019-10-14',
#   'doctor': 'Laura Myers',
#   'hospital': 'LLC Martin',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '4397.776995413336',
#   'room_number': '481',
#   'admission_type': 'Urgent',
#   'discharge_date': '2019-10-19',
#   'medication': 'Paracetamol',
#   'test_results': 'Inconclusive'},
#  {'name': 'CasSAndrA Robinson',
#   'age': '26',
#   'gender': 'Female',
#   'blood_type': 'B-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2021-12-19',
#   'doctor': 'Travis Parsons',
#   'hospital': 'Espinoza-Stone',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '9380.325967528432',
#   'room_number': '212',
#   'admission_type': 'Urgent',
#   'discharge_date': '2022-01-16',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'NIcOlE LUcErO',
#   'age': '70',
#   'gender': 'Female',
#   'blood_type': 'O-',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2022-03-12',
#   'doctor': 'Christine Johnson',
#   'hospital': 'and Garcia Morris Cunningham,',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '48290.69340736419',
#   'room_number': '113',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-03-29',
#   'medication': 'Lipitor',
#   'test_results': 'Abnormal'},
#  {'name': 'PAmela fErNanDeZ',
#   'age': '57',
#   'gender': 'Female',
#   'blood_type': 'B-',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2021-01-17',
#   'doctor': 'Emily Taylor',
#   'hospital': 'Walton-Meyer',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '32973.94083296627',
#   'room_number': '272',
#   'admission_type': 'Urgent',
#   'discharge_date': '2021-01-29',
#   'medication': 'Penicillin',
#   'test_results': 'Abnormal'},
#  {'name': 'chRiSTOPHer LEe',
#   'age': '74',
#   'gender': 'Female',
#   'blood_type': 'B-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2021-09-15',
#   'doctor': 'William Reynolds',
#   'hospital': 'PLC Young',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '49943.27849878726',
#   'room_number': '478',
#   'admission_type': 'Emergency',
#   'discharge_date': '2021-10-05',
#   'medication': 'Lipitor',
#   'test_results': 'Normal'},
#  {'name': 'ThomAS morsE',
#   'age': '81',
#   'gender': 'Male',
#   'blood_type': 'A+',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2020-01-27',
#   'doctor': 'Jennifer Carter',
#   'hospital': 'Meadows Group',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '35633.95545438785',
#   'room_number': '196',
#   'admission_type': 'Urgent',
#   'discharge_date': '2020-02-09',
#   'medication': 'Aspirin',
#   'test_results': 'Normal'},
#  {'name': 'Mr. eRiC Lane',
#   'age': '49',
#   'gender': 'Female',
#   'blood_type': 'A-',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2022-06-24',
#   'doctor': 'Matthew Thomas',
#   'hospital': 'and Howell Brooks, Rogers',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '25966.328610220968',
#   'room_number': '418',
#   'admission_type': 'Elective',
#   'discharge_date': '2022-07-18',
#   'medication': 'Paracetamol',
#   'test_results': 'Normal'},
#  {'name': 'KAThEriNE SmiTH',
#   'age': '26',
#   'gender': 'Female',
#   'blood_type': 'AB+',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2021-06-09',
#   'doctor': 'Mary Logan',
#   'hospital': 'and Mcclure White Boone,',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '21784.44507072369',
#   'room_number': '410',
#   'admission_type': 'Urgent',
#   'discharge_date': '2021-07-01',
#   'medication': 'Paracetamol',
#   'test_results': 'Normal'},
#  {'name': 'pAUL wILLiAmS',
#   'age': '81',
#   'gender': 'Female',
#   'blood_type': 'AB-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2020-08-23',
#   'doctor': 'Kristin Martinez',
#   'hospital': 'Gates Brown, and Stuart',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '42684.55888455027',
#   'room_number': '328',
#   'admission_type': 'Urgent',
#   'discharge_date': '2020-09-08',
#   'medication': 'Penicillin',
#   'test_results': 'Abnormal'},
#  {'name': 'lYNn MaRtinez',
#   'age': '65',
#   'gender': 'Male',
#   'blood_type': 'O+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2022-10-12',
#   'doctor': 'Daniel Murphy',
#   'hospital': 'Group Armstrong',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '45585.8865599394',
#   'room_number': '300',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-11-02',
#   'medication': 'Penicillin',
#   'test_results': 'Normal'},
#  {'name': 'chRIsTOpHEr CHaPmAN',
#   'age': '31',
#   'gender': 'Female',
#   'blood_type': 'O+',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2021-12-01',
#   'doctor': 'Emily Patterson',
#   'hospital': 'Ltd Schwartz',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '29615.441863646167',
#   'room_number': '211',
#   'admission_type': 'Elective',
#   'discharge_date': '2021-12-09',
#   'medication': 'Paracetamol',
#   'test_results': 'Normal'},
#  {'name': 'CHRis fRYe',
#   'age': '58',
#   'gender': 'Male',
#   'blood_type': 'A-',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2020-05-04',
#   'doctor': 'Heather Smith',
#   'hospital': 'Nelson-Phillips',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '36992.27368828386',
#   'room_number': '413',
#   'admission_type': 'Urgent',
#   'discharge_date': '2020-05-13',
#   'medication': 'Aspirin',
#   'test_results': 'Normal'},
#  {'name': 'kyLE bEnneTT',
#   'age': '22',
#   'gender': 'Male',
#   'blood_type': 'O+',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2023-09-09',
#   'doctor': 'John Smith',
#   'hospital': 'Knight and Nguyen, Riggs',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '28051.499483946325',
#   'room_number': '157',
#   'admission_type': 'Urgent',
#   'discharge_date': '2023-09-23',
#   'medication': 'Ibuprofen',
#   'test_results': 'Abnormal'},
#  {'name': 'BRandOn coLLINS',
#   'age': '77',
#   'gender': 'Female',
#   'blood_type': 'O+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2019-07-19',
#   'doctor': 'Cameron Young',
#   'hospital': 'Lopez PLC',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '16320.232447271888',
#   'room_number': '138',
#   'admission_type': 'Urgent',
#   'discharge_date': '2019-07-29',
#   'medication': 'Ibuprofen',
#   'test_results': 'Abnormal'},
#  {'name': 'mIchael LiU',
#   'age': '30',
#   'gender': 'Male',
#   'blood_type': 'AB-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2024-04-05',
#   'doctor': 'Vicki Nguyen',
#   'hospital': 'Fernandez and Phillips, Singh',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '30590.54180634067',
#   'room_number': '456',
#   'admission_type': 'Emergency',
#   'discharge_date': '2024-04-22',
#   'medication': 'Paracetamol',
#   'test_results': 'Inconclusive'},
#  {'name': 'STepHaNie kEnt',
#   'age': '42',
#   'gender': 'Female',
#   'blood_type': 'A-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2019-06-15',
#   'doctor': 'Mary Moss',
#   'hospital': 'Beck-Galloway',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '14681.016360125932',
#   'room_number': '234',
#   'admission_type': 'Emergency',
#   'discharge_date': '2019-07-05',
#   'medication': 'Ibuprofen',
#   'test_results': 'Abnormal'},
#  {'name': 'JessE BaNks',
#   'age': '67',
#   'gender': 'Female',
#   'blood_type': 'AB+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2022-10-29',
#   'doctor': 'Alexander Garcia',
#   'hospital': 'Decker Glover, and Christensen',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '21879.53191106356',
#   'room_number': '492',
#   'admission_type': 'Urgent',
#   'discharge_date': '2022-11-20',
#   'medication': 'Penicillin',
#   'test_results': 'Inconclusive'},
#  {'name': 'PeGGY LEe',
#   'age': '24',
#   'gender': 'Female',
#   'blood_type': 'A-',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2022-04-08',
#   'doctor': 'Patrick Burns',
#   'hospital': 'Nelson Walker Myers, and',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '6767.634396544945',
#   'room_number': '180',
#   'admission_type': 'Elective',
#   'discharge_date': '2022-04-13',
#   'medication': 'Lipitor',
#   'test_results': 'Abnormal'},
#  {'name': 'TAmARa hErNAndez',
#   'age': '84',
#   'gender': 'Female',
#   'blood_type': 'B-',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2023-08-17',
#   'doctor': 'Kayla Powers',
#   'hospital': 'Mitchell-Navarro',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '19973.46292615957',
#   'room_number': '250',
#   'admission_type': 'Elective',
#   'discharge_date': '2023-09-11',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'mR. DAVID pIERce Md',
#   'age': '73',
#   'gender': 'Female',
#   'blood_type': 'A-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2023-11-05',
#   'doctor': 'Julia Cox',
#   'hospital': 'Group Delgado',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '14362.31448750232',
#   'room_number': '296',
#   'admission_type': 'Emergency',
#   'discharge_date': '2023-11-07',
#   'medication': 'Paracetamol',
#   'test_results': 'Inconclusive'},
#  {'name': 'beThaNY MoOrE',
#   'age': '55',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2023-04-09',
#   'doctor': 'Penny Pruitt',
#   'hospital': 'and Montes Graves, Thomas',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '10300.65731137592',
#   'room_number': '330',
#   'admission_type': 'Emergency',
#   'discharge_date': '2023-04-21',
#   'medication': 'Paracetamol',
#   'test_results': 'Normal'},
#  {'name': 'MIChael MIllS',
#   'age': '23',
#   'gender': 'Male',
#   'blood_type': 'O-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2022-09-21',
#   'doctor': 'Mrs. Lori Hurst PhD',
#   'hospital': 'Hall-Bentley',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '37951.66490984979',
#   'room_number': '405',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-09-25',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'kyle Wiley',
#   'age': '40',
#   'gender': 'Female',
#   'blood_type': 'AB-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2021-01-21',
#   'doctor': 'Stephen Carr',
#   'hospital': 'Taylor-Nguyen',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '6733.990947068834',
#   'room_number': '300',
#   'admission_type': 'Urgent',
#   'discharge_date': '2021-02-06',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'jACqUeLINE jORdaN',
#   'age': '51',
#   'gender': 'Male',
#   'blood_type': 'O+',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2020-07-10',
#   'doctor': 'Jacob Daniel',
#   'hospital': 'Hunter-Grant',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '17839.745651647165',
#   'room_number': '306',
#   'admission_type': 'Elective',
#   'discharge_date': '2020-07-20',
#   'medication': 'Paracetamol',
#   'test_results': 'Abnormal'},
#  {'name': 'ASHleY guTIERreZ',
#   'age': '83',
#   'gender': 'Male',
#   'blood_type': 'AB+',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2019-11-06',
#   'doctor': 'Tyler Braun',
#   'hospital': 'Miller-Lawson',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '24637.090064033247',
#   'room_number': '333',
#   'admission_type': 'Elective',
#   'discharge_date': '2019-11-22',
#   'medication': 'Paracetamol',
#   'test_results': 'Inconclusive'},
#  {'name': 'Kim ScOtt',
#   'age': '63',
#   'gender': 'Male',
#   'blood_type': 'A-',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2024-04-07',
#   'doctor': 'Cindy Ellis',
#   'hospital': 'Scott-Kelly',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '39723.16605142787',
#   'room_number': '244',
#   'admission_type': 'Emergency',
#   'discharge_date': '2024-05-04',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'tRAvIs carTeR',
#   'age': '18',
#   'gender': 'Male',
#   'blood_type': 'A+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2022-07-06',
#   'doctor': 'Megan Hahn',
#   'hospital': 'Moss and Ferguson, Baker',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '48407.38629110051',
#   'room_number': '325',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-07-18',
#   'medication': 'Aspirin',
#   'test_results': 'Normal'},
#  {'name': 'LArry rodgeRs',
#   'age': '23',
#   'gender': 'Female',
#   'blood_type': 'B-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2022-08-03',
#   'doctor': 'Eric Kelly',
#   'hospital': 'and Mason Smith Chase,',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '5517.393642223992',
#   'room_number': '113',
#   'admission_type': 'Elective',
#   'discharge_date': '2022-08-10',
#   'medication': 'Aspirin',
#   'test_results': 'Inconclusive'},
#  {'name': 'Nancy glOVeR',
#   'age': '58',
#   'gender': 'Male',
#   'blood_type': 'A-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2020-05-08',
#   'doctor': 'Jennifer Larson',
#   'hospital': 'Khan, and Rodriguez Fischer',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '19183.168885395546',
#   'room_number': '378',
#   'admission_type': 'Emergency',
#   'discharge_date': '2020-06-01',
#   'medication': 'Aspirin',
#   'test_results': 'Abnormal'},
#  {'name': 'JessIca king',
#   'age': '27',
#   'gender': 'Male',
#   'blood_type': 'AB-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2019-12-09',
#   'doctor': 'William Hess',
#   'hospital': 'Sons Watson and',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '8320.660803287437',
#   'room_number': '468',
#   'admission_type': 'Urgent',
#   'discharge_date': '2019-12-21',
#   'medication': 'Lipitor',
#   'test_results': 'Abnormal'},
#  {'name': 'ChRiStOPhER gOnzAlez',
#   'age': '59',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2019-11-21',
#   'doctor': 'Patricia Dunn',
#   'hospital': 'Rhodes-Carey',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '10107.18765105721',
#   'room_number': '368',
#   'admission_type': 'Emergency',
#   'discharge_date': '2019-12-08',
#   'medication': 'Penicillin',
#   'test_results': 'Abnormal'},
#  {'name': 'jOhN hARTmAN',
#   'age': '27',
#   'gender': 'Male',
#   'blood_type': 'B-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2023-01-07',
#   'doctor': 'Jack Jackson',
#   'hospital': 'Bullock-Ramsey',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '49402.29837252711',
#   'room_number': '263',
#   'admission_type': 'Elective',
#   'discharge_date': '2023-01-27',
#   'medication': 'Lipitor',
#   'test_results': 'Inconclusive'},
#  {'name': 'MicHAEl MillEr',
#   'age': '31',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2024-02-06',
#   'doctor': 'Jonathan Drake',
#   'hospital': 'Clark Brown, and Myers',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '35776.81511145377',
#   'room_number': '489',
#   'admission_type': 'Emergency',
#   'discharge_date': '2024-02-10',
#   'medication': 'Penicillin',
#   'test_results': 'Normal'},
#  {'name': 'Erica myERS',
#   'age': '19',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2020-01-30',
#   'doctor': 'Ian Benitez',
#   'hospital': 'Jackson and Lane, Dillon',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '20227.86372674477',
#   'room_number': '241',
#   'admission_type': 'Elective',
#   'discharge_date': '2020-02-12',
#   'medication': 'Penicillin',
#   'test_results': 'Normal'},
#  {'name': 'cAROl PaTtERSoN',
#   'age': '29',
#   'gender': 'Female',
#   'blood_type': 'O+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2022-10-24',
#   'doctor': 'Jamie Baker',
#   'hospital': 'Turner Cook, Banks and',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '19328.118579079928',
#   'room_number': '231',
#   'admission_type': 'Urgent',
#   'discharge_date': '2022-11-07',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'JOSe LopEz',
#   'age': '18',
#   'gender': 'Male',
#   'blood_type': 'A-',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2022-01-09',
#   'doctor': 'Erika Jackson',
#   'hospital': 'Miles, and Weaver Hudson',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '46956.54573063246',
#   'room_number': '377',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-01-15',
#   'medication': 'Aspirin',
#   'test_results': 'Inconclusive'},
#  {'name': 'kEVIn SiMmoNs Jr.',
#   'age': '24',
#   'gender': 'Male',
#   'blood_type': 'AB-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2023-12-28',
#   'doctor': 'Amanda Garcia',
#   'hospital': 'Evans Ltd',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '10709.690388900191',
#   'room_number': '407',
#   'admission_type': 'Emergency',
#   'discharge_date': '2024-01-02',
#   'medication': 'Paracetamol',
#   'test_results': 'Abnormal'},
#  {'name': 'DuANe HaneY',
#   'age': '27',
#   'gender': 'Male',
#   'blood_type': 'AB-',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2021-09-16',
#   'doctor': 'Raven Wong',
#   'hospital': 'Sons and Schaefer',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '45353.99077738541',
#   'room_number': '263',
#   'admission_type': 'Urgent',
#   'discharge_date': '2021-10-14',
#   'medication': 'Penicillin',
#   'test_results': 'Abnormal'},
#  {'name': 'JONathAn yaTeS',
#   'age': '57',
#   'gender': 'Female',
#   'blood_type': 'AB-',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2023-07-24',
#   'doctor': 'Cynthia Scott',
#   'hospital': 'Sons Hodges and',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '8451.001758478955',
#   'room_number': '135',
#   'admission_type': 'Elective',
#   'discharge_date': '2023-08-11',
#   'medication': 'Paracetamol',
#   'test_results': 'Abnormal'},
#  {'name': 'johN THoMaS',
#   'age': '74',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2021-11-13',
#   'doctor': 'Mark Padilla',
#   'hospital': 'Simpson-Mccall',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '29850.879728183794',
#   'room_number': '131',
#   'admission_type': 'Emergency',
#   'discharge_date': '2021-12-07',
#   'medication': 'Paracetamol',
#   'test_results': 'Inconclusive'},
#  {'name': 'AdriaN BuckLEY',
#   'age': '22',
#   'gender': 'Female',
#   'blood_type': 'A-',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2023-10-11',
#   'doctor': 'Julie Ramirez',
#   'hospital': 'Lin Thompson Wells, and',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '42696.52116389919',
#   'room_number': '102',
#   'admission_type': 'Urgent',
#   'discharge_date': '2023-10-27',
#   'medication': 'Penicillin',
#   'test_results': 'Normal'},
#  {'name': 'apRil SANTIAgO',
#   'age': '33',
#   'gender': 'Female',
#   'blood_type': 'B-',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2021-01-30',
#   'doctor': 'Jacob Rich',
#   'hospital': 'Jones-Scott',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '2305.139139538494',
#   'room_number': '249',
#   'admission_type': 'Emergency',
#   'discharge_date': '2021-02-04',
#   'medication': 'Penicillin',
#   'test_results': 'Inconclusive'},
#  {'name': 'DIane scHultz',
#   'age': '57',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2021-11-21',
#   'doctor': 'Mark Hartman Jr.',
#   'hospital': 'Howe-Kelly',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '44437.47067335722',
#   'room_number': '255',
#   'admission_type': 'Emergency',
#   'discharge_date': '2021-12-05',
#   'medication': 'Penicillin',
#   'test_results': 'Inconclusive'},
#  {'name': 'tiMOThY myers',
#   'age': '61',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2024-03-02',
#   'doctor': 'Timothy Baker',
#   'hospital': 'and Sons Reyes',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '29504.387442211457',
#   'room_number': '422',
#   'admission_type': 'Urgent',
#   'discharge_date': '2024-03-26',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'NICOLE HUGhes',
#   'age': '20',
#   'gender': 'Male',
#   'blood_type': 'O+',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2020-12-04',
#   'doctor': 'Lori Sanchez',
#   'hospital': 'Shaw-Young',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '34617.788344937246',
#   'room_number': '320',
#   'admission_type': 'Emergency',
#   'discharge_date': '2020-12-08',
#   'medication': 'Ibuprofen',
#   'test_results': 'Abnormal'},
#  {'name': 'ChAd MorEnO',
#   'age': '67',
#   'gender': 'Male',
#   'blood_type': 'AB+',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2020-08-26',
#   'doctor': 'Connie Boyd',
#   'hospital': 'Inc Skinner',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '46814.011195111656',
#   'room_number': '134',
#   'admission_type': 'Urgent',
#   'discharge_date': '2020-08-27',
#   'medication': 'Penicillin',
#   'test_results': 'Abnormal'},
#  {'name': 'SeaN jenniNGs',
#   'age': '80',
#   'gender': 'Female',
#   'blood_type': 'AB-',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2023-11-12',
#   'doctor': 'James Tucker',
#   'hospital': 'Clark-Johnson',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '20257.54428293241',
#   'room_number': '255',
#   'admission_type': 'Elective',
#   'discharge_date': '2023-12-12',
#   'medication': 'Penicillin',
#   'test_results': 'Abnormal'},
#  {'name': 'DIAnE brAnch',
#   'age': '44',
#   'gender': 'Male',
#   'blood_type': 'O+',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2020-05-30',
#   'doctor': 'Juan Acevedo',
#   'hospital': 'Perez and Sons',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '22841.36387690568',
#   'room_number': '410',
#   'admission_type': 'Emergency',
#   'discharge_date': '2020-06-14',
#   'medication': 'Aspirin',
#   'test_results': 'Inconclusive'},
#  {'name': 'cindY OROzco',
#   'age': '26',
#   'gender': 'Female',
#   'blood_type': 'B-',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2023-05-12',
#   'doctor': 'Julie Finley',
#   'hospital': 'Kemp LLC',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '10283.716858129152',
#   'room_number': '273',
#   'admission_type': 'Emergency',
#   'discharge_date': '2023-06-10',
#   'medication': 'Ibuprofen',
#   'test_results': 'Abnormal'},
#  {'name': 'pAtriCIa MEdinA',
#   'age': '80',
#   'gender': 'Male',
#   'blood_type': 'AB+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2022-07-07',
#   'doctor': 'Miguel Parker',
#   'hospital': 'LLC Dixon',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '1586.476601438285',
#   'room_number': '395',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-07-23',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'kayLa padillA',
#   'age': '63',
#   'gender': 'Male',
#   'blood_type': 'B-',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2020-09-24',
#   'doctor': 'Jermaine Peters',
#   'hospital': 'and Morales Jennings Cook,',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '34774.351127057584',
#   'room_number': '152',
#   'admission_type': 'Emergency',
#   'discharge_date': '2020-10-08',
#   'medication': 'Penicillin',
#   'test_results': 'Inconclusive'},
#  {'name': 'JUan klEiN',
#   'age': '58',
#   'gender': 'Female',
#   'blood_type': 'B-',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2023-08-19',
#   'doctor': 'Lisa Edwards',
#   'hospital': 'Group Hood',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '24870.10365893384',
#   'room_number': '321',
#   'admission_type': 'Emergency',
#   'discharge_date': '2023-08-25',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'wILLIAM hIlL',
#   'age': '38',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2023-05-16',
#   'doctor': 'Matthew Walker',
#   'hospital': 'Lindsey Inc',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '39476.94751437997',
#   'room_number': '428',
#   'admission_type': 'Elective',
#   'discharge_date': '2023-06-01',
#   'medication': 'Aspirin',
#   'test_results': 'Abnormal'},
#  {'name': 'CARL BEst',
#   'age': '60',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2022-08-22',
#   'doctor': 'Gregory Hansen',
#   'hospital': 'Ltd Wang',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '26062.43432029105',
#   'room_number': '482',
#   'admission_type': 'Elective',
#   'discharge_date': '2022-09-07',
#   'medication': 'Paracetamol',
#   'test_results': 'Inconclusive'},
#  {'name': 'TInA GriFfin',
#   'age': '49',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2022-06-17',
#   'doctor': 'Jessica Cruz',
#   'hospital': 'Inc Ford',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '25302.112634011213',
#   'room_number': '268',
#   'admission_type': 'Elective',
#   'discharge_date': '2022-06-28',
#   'medication': 'Penicillin',
#   'test_results': 'Abnormal'},
#  {'name': 'MR. TYler TAYLOR Phd',
#   'age': '80',
#   'gender': 'Male',
#   'blood_type': 'A+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2022-11-05',
#   'doctor': 'Robert Salazar',
#   'hospital': 'Dean-Hawkins',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '10661.51064913277',
#   'room_number': '120',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-11-25',
#   'medication': 'Lipitor',
#   'test_results': 'Abnormal'},
#  {'name': 'TAyLoR howeLl Dds',
#   'age': '35',
#   'gender': 'Female',
#   'blood_type': 'B+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2021-09-10',
#   'doctor': 'Kyle Patterson',
#   'hospital': 'Walter PLC',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '30358.1945795447',
#   'room_number': '318',
#   'admission_type': 'Elective',
#   'discharge_date': '2021-09-18',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'mIcHAeL MaRTIn',
#   'age': '84',
#   'gender': 'Male',
#   'blood_type': 'A+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2022-09-06',
#   'doctor': 'John Summers',
#   'hospital': 'Sons Horn and',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '23684.52547274483',
#   'room_number': '162',
#   'admission_type': 'Urgent',
#   'discharge_date': '2022-09-27',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'heatHER mIller',
#   'age': '76',
#   'gender': 'Male',
#   'blood_type': 'A+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2021-04-17',
#   'doctor': 'Scott Grant',
#   'hospital': 'Powell Ward, and Mercado',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '3908.9465679463137',
#   'room_number': '428',
#   'admission_type': 'Elective',
#   'discharge_date': '2021-05-10',
#   'medication': 'Lipitor',
#   'test_results': 'Inconclusive'},
#  {'name': 'cathERinE gArDnEr',
#   'age': '79',
#   'gender': 'Female',
#   'blood_type': 'A-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2019-08-19',
#   'doctor': 'David Ruiz',
#   'hospital': 'James Ltd',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '25503.673806852043',
#   'room_number': '144',
#   'admission_type': 'Elective',
#   'discharge_date': '2019-08-26',
#   'medication': 'Lipitor',
#   'test_results': 'Abnormal'},
#  {'name': 'ANNE THOMPSoN',
#   'age': '76',
#   'gender': 'Female',
#   'blood_type': 'O+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2024-03-24',
#   'doctor': 'Kyle Smith',
#   'hospital': 'Kemp-Munoz',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '6312.607691018524',
#   'room_number': '226',
#   'admission_type': 'Elective',
#   'discharge_date': '2024-04-14',
#   'medication': 'Aspirin',
#   'test_results': 'Abnormal'},
#  {'name': 'TOdd coopeR',
#   'age': '55',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2022-12-10',
#   'doctor': 'Jason Price',
#   'hospital': 'Henderson-Taylor',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '21772.34139864964',
#   'room_number': '459',
#   'admission_type': 'Elective',
#   'discharge_date': '2022-12-31',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'PhILLIP lyOnS',
#   'age': '53',
#   'gender': 'Male',
#   'blood_type': 'B-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2022-09-14',
#   'doctor': 'Stephanie Clements',
#   'hospital': 'Parsons, Hartman Martinez and',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '30437.001787641067',
#   'room_number': '208',
#   'admission_type': 'Elective',
#   'discharge_date': '2022-09-18',
#   'medication': 'Aspirin',
#   'test_results': 'Normal'},
#  {'name': 'MaRk foRD',
#   'age': '18',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2022-10-18',
#   'doctor': 'Steven James',
#   'hospital': 'Luna Inc',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '28837.6770525072',
#   'room_number': '227',
#   'admission_type': 'Elective',
#   'discharge_date': '2022-11-11',
#   'medication': 'Aspirin',
#   'test_results': 'Abnormal'},
#  {'name': 'mARcUS ZAmorA',
#   'age': '69',
#   'gender': 'Male',
#   'blood_type': 'O+',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2021-11-13',
#   'doctor': 'Jeremiah Wolf',
#   'hospital': 'Hernandez, Ritter and Huffman',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '25425.72786260709',
#   'room_number': '115',
#   'admission_type': 'Elective',
#   'discharge_date': '2021-11-21',
#   'medication': 'Aspirin',
#   'test_results': 'Normal'},
#  {'name': 'KaTiE hENry',
#   'age': '70',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2022-07-08',
#   'doctor': 'Roberto Petersen',
#   'hospital': 'Reed LLC',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '7187.272346099509',
#   'room_number': '402',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-07-25',
#   'medication': 'Aspirin',
#   'test_results': 'Normal'},
#  {'name': 'wilLIAm morTON',
#   'age': '21',
#   'gender': 'Male',
#   'blood_type': 'A+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2023-06-25',
#   'doctor': 'Christina Hammond',
#   'hospital': 'Thompson-Walker',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '3125.7364766012533',
#   'room_number': '442',
#   'admission_type': 'Urgent',
#   'discharge_date': '2023-07-11',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'KaTRina maRTin',
#   'age': '47',
#   'gender': 'Male',
#   'blood_type': 'A-',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2019-07-09',
#   'doctor': 'Patricia Colon',
#   'hospital': 'Group Nguyen',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '31516.10073437436',
#   'room_number': '418',
#   'admission_type': 'Elective',
#   'discharge_date': '2019-08-05',
#   'medication': 'Penicillin',
#   'test_results': 'Inconclusive'},
#  {'name': 'HunTeR mckAy',
#   'age': '85',
#   'gender': 'Male',
#   'blood_type': 'A-',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2021-05-14',
#   'doctor': 'Dominic Mitchell',
#   'hospital': 'Newton-White',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '40014.7623484579',
#   'room_number': '425',
#   'admission_type': 'Emergency',
#   'discharge_date': '2021-06-03',
#   'medication': 'Aspirin',
#   'test_results': 'Abnormal'},
#  {'name': 'dWAYnE DAViS',
#   'age': '28',
#   'gender': 'Male',
#   'blood_type': 'O+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2024-01-15',
#   'doctor': 'Wendy Davis',
#   'hospital': 'Ltd Thomas',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '40782.92780848658',
#   'room_number': '373',
#   'admission_type': 'Elective',
#   'discharge_date': '2024-02-07',
#   'medication': 'Ibuprofen',
#   'test_results': 'Abnormal'},
#  {'name': 'sARAH CalDweLL',
#   'age': '62',
#   'gender': 'Male',
#   'blood_type': 'A-',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2019-09-30',
#   'doctor': 'Daniel Carson',
#   'hospital': 'Pierce Ward, Torres and',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '3879.0846018133934',
#   'room_number': '290',
#   'admission_type': 'Elective',
#   'discharge_date': '2019-10-15',
#   'medication': 'Aspirin',
#   'test_results': 'Inconclusive'},
# ...
#   'billing_amount': '16055.930395419682',
#   'room_number': '393',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-02-05',
#   'medication': 'Aspirin',
#   'test_results': 'Inconclusive'},
#  {'name': 'Jacob youNG',
#   'age': '40',
#   'gender': 'Male',
#   'blood_type': 'AB+',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2023-09-25',
#   'doctor': 'Tara Tucker',
#   'hospital': 'PLC Aguirre',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '30123.538567926087',
#   'room_number': '423',
#   'admission_type': 'Urgent',
#   'discharge_date': '2023-10-05',
#   'medication': 'Aspirin',
#   'test_results': 'Normal'},
#  {'name': 'amY RAMos',
#   'age': '70',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2021-10-28',
#   'doctor': 'Dustin Alvarez',
#   'hospital': 'Nelson Baldwin, Boyd and',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '38572.16947791579',
#   'room_number': '123',
#   'admission_type': 'Emergency',
#   'discharge_date': '2021-10-31',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'PaTricK moRAlES',
#   'age': '56',
#   'gender': 'Female',
#   'blood_type': 'AB-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2020-06-16',
#   'doctor': 'Jessica Conway',
#   'hospital': 'Martinez, and Moore White',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '37798.95058783797',
#   'room_number': '392',
#   'admission_type': 'Urgent',
#   'discharge_date': '2020-07-14',
#   'medication': 'Ibuprofen',
#   'test_results': 'Abnormal'},
#  {'name': 'sOpHIA cONwAY',
#   'age': '25',
#   'gender': 'Male',
#   'blood_type': 'O+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2021-10-07',
#   'doctor': 'Heidi Wood',
#   'hospital': 'Barker, Costa Hahn and',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '38716.355934862506',
#   'room_number': '283',
#   'admission_type': 'Emergency',
#   'discharge_date': '2021-11-06',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'jamES mOORE',
#   'age': '20',
#   'gender': 'Male',
#   'blood_type': 'A-',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2021-04-29',
#   'doctor': 'David Gordon',
#   'hospital': 'Anderson and Higgins Galvan,',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '13666.283370731851',
#   'room_number': '471',
#   'admission_type': 'Elective',
#   'discharge_date': '2021-05-17',
#   'medication': 'Paracetamol',
#   'test_results': 'Inconclusive'},
#  {'name': 'ChRisTOPHeR cOChRan',
#   'age': '73',
#   'gender': 'Female',
#   'blood_type': 'AB-',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2019-05-12',
#   'doctor': 'Jonathan Thomas',
#   'hospital': 'Flores-Roman',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '30753.68882330775',
#   'room_number': '236',
#   'admission_type': 'Elective',
#   'discharge_date': '2019-06-07',
#   'medication': 'Lipitor',
#   'test_results': 'Abnormal'},
#  {'name': 'RObeRT Carter',
#   'age': '82',
#   'gender': 'Male',
#   'blood_type': 'B-',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2021-09-12',
#   'doctor': 'Lori Diaz',
#   'hospital': 'Miller, Moon Boyd and',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '44278.23165677635',
#   'room_number': '295',
#   'admission_type': 'Elective',
#   'discharge_date': '2021-09-17',
#   'medication': 'Aspirin',
#   'test_results': 'Inconclusive'},
#  {'name': 'moRgAn NGUYEn',
#   'age': '31',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2021-01-25',
#   'doctor': 'Martin Dominguez',
#   'hospital': 'Inc Harmon',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '6267.540561718074',
#   'room_number': '140',
#   'admission_type': 'Urgent',
#   'discharge_date': '2021-01-27',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'natHAn MONToYA',
#   'age': '74',
#   'gender': 'Male',
#   'blood_type': 'O-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2020-05-22',
#   'doctor': 'Adam Roberts',
#   'hospital': 'Elliott Jones Hinton, and',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '26276.792663524604',
#   'room_number': '242',
#   'admission_type': 'Elective',
#   'discharge_date': '2020-06-17',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'jOE Berry PhD',
#   'age': '38',
#   'gender': 'Female',
#   'blood_type': 'B-',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2022-06-20',
#   'doctor': 'Nancy Beck',
#   'hospital': 'Sons Mckinney and',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '33171.03008875718',
#   'room_number': '319',
#   'admission_type': 'Elective',
#   'discharge_date': '2022-07-14',
#   'medication': 'Aspirin',
#   'test_results': 'Inconclusive'},
#  {'name': 'daNIeL oRtiz',
#   'age': '63',
#   'gender': 'Female',
#   'blood_type': 'AB-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2020-11-16',
#   'doctor': 'Christy Hughes',
#   'hospital': 'Carroll-Howard',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '44984.24155625038',
#   'room_number': '124',
#   'admission_type': 'Elective',
#   'discharge_date': '2020-12-06',
#   'medication': 'Paracetamol',
#   'test_results': 'Normal'},
#  {'name': 'mATthEw cLaRk',
#   'age': '62',
#   'gender': 'Female',
#   'blood_type': 'B-',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2020-10-09',
#   'doctor': 'Charles Hernandez',
#   'hospital': 'and Park, Garcia Lam',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '27091.86037319376',
#   'room_number': '315',
#   'admission_type': 'Urgent',
#   'discharge_date': '2020-10-14',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'JAcQuELINE hArDY',
#   'age': '80',
#   'gender': 'Male',
#   'blood_type': 'O+',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2023-12-12',
#   'doctor': 'Hannah Clay',
#   'hospital': 'Chavez Valenzuela, and Gutierrez',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '32387.92514860232',
#   'room_number': '264',
#   'admission_type': 'Urgent',
#   'discharge_date': '2023-12-27',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'eMiLY JoSEPh',
#   'age': '25',
#   'gender': 'Female',
#   'blood_type': 'AB-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2022-06-14',
#   'doctor': 'Steven Dixon',
#   'hospital': 'Hill-Hernandez',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '32905.47679380129',
#   'room_number': '289',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-07-03',
#   'medication': 'Lipitor',
#   'test_results': 'Abnormal'},
#  {'name': 'sarAH HiCKs',
#   'age': '51',
#   'gender': 'Male',
#   'blood_type': 'A-',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2023-02-23',
#   'doctor': 'Monica Thomas',
#   'hospital': 'Skinner LLC',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '1332.3384328468917',
#   'room_number': '489',
#   'admission_type': 'Emergency',
#   'discharge_date': '2023-03-18',
#   'medication': 'Aspirin',
#   'test_results': 'Abnormal'},
#  {'name': 'bRiANa rOsS',
#   'age': '46',
#   'gender': 'Female',
#   'blood_type': 'AB+',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2024-04-25',
#   'doctor': 'Alexander Moore',
#   'hospital': 'Inc Cox',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '17702.569386018386',
#   'room_number': '385',
#   'admission_type': 'Urgent',
#   'discharge_date': '2024-05-12',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'maRY mcculLOUgH',
#   'age': '18',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2022-06-08',
#   'doctor': 'Curtis Mckinney',
#   'hospital': 'Perez Sons and',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '33443.55248615018',
#   'room_number': '342',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-06-22',
#   'medication': 'Penicillin',
#   'test_results': 'Normal'},
#  {'name': 'bRIAn OSborNe',
#   'age': '30',
#   'gender': 'Female',
#   'blood_type': 'B-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2023-12-07',
#   'doctor': 'Stephanie Shepard',
#   'hospital': 'Parker Turner, Houston and',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '23175.497028595324',
#   'room_number': '326',
#   'admission_type': 'Emergency',
#   'discharge_date': '2023-12-24',
#   'medication': 'Ibuprofen',
#   'test_results': 'Normal'},
#  {'name': 'suSAn WALTerS',
#   'age': '43',
#   'gender': 'Male',
#   'blood_type': 'AB-',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2020-11-03',
#   'doctor': 'Russell Soto',
#   'hospital': 'Wilson-Chen',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '14224.312292911767',
#   'room_number': '426',
#   'admission_type': 'Emergency',
#   'discharge_date': '2020-12-01',
#   'medication': 'Paracetamol',
#   'test_results': 'Abnormal'},
#  {'name': 'CATHerine HaRVEY',
#   'age': '21',
#   'gender': 'Male',
#   'blood_type': 'AB+',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2023-10-03',
#   'doctor': 'Charles Cardenas',
#   'hospital': 'Boone-Duffy',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '23483.49684387744',
#   'room_number': '357',
#   'admission_type': 'Urgent',
#   'discharge_date': '2023-10-18',
#   'medication': 'Paracetamol',
#   'test_results': 'Normal'},
#  {'name': 'cORY PIERCe',
#   'age': '28',
#   'gender': 'Female',
#   'blood_type': 'B-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2022-06-11',
#   'doctor': 'Brandon Montoya',
#   'hospital': 'Reid-Simmons',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '31326.72671721238',
#   'room_number': '299',
#   'admission_type': 'Emergency',
#   'discharge_date': '2022-06-28',
#   'medication': 'Paracetamol',
#   'test_results': 'Abnormal'},
#  {'name': 'jeSus jORdan',
#   'age': '26',
#   'gender': 'Female',
#   'blood_type': 'O-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2021-07-03',
#   'doctor': 'Andrew Bishop',
#   'hospital': 'Dunn-Bentley',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '48651.7366550091',
#   'room_number': '124',
#   'admission_type': 'Urgent',
#   'discharge_date': '2021-07-29',
#   'medication': 'Penicillin',
#   'test_results': 'Inconclusive'},
#  {'name': 'ANn dUNCAN',
#   'age': '24',
#   'gender': 'Male',
#   'blood_type': 'A-',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2024-03-19',
#   'doctor': 'Daniel Sanders',
#   'hospital': 'Inc Cherry',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '18932.31466702556',
#   'room_number': '115',
#   'admission_type': 'Elective',
#   'discharge_date': '2024-04-02',
#   'medication': 'Penicillin',
#   'test_results': 'Inconclusive'},
#  {'name': 'Sarah pOrTEr',
#   'age': '55',
#   'gender': 'Female',
#   'blood_type': 'AB-',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2024-01-11',
#   'doctor': 'Jeremiah Nunez',
#   'hospital': 'Zavala-Fernandez',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '22063.229031651204',
#   'room_number': '147',
#   'admission_type': 'Elective',
#   'discharge_date': '2024-01-30',
#   'medication': 'Paracetamol',
#   'test_results': 'Inconclusive'},
#  {'name': 'jACquEliNE DeAN',
#   'age': '41',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Cancer',
#   'date_of_admission': '2021-06-26',
#   'doctor': 'Carolyn Peters',
#   'hospital': 'Jones-Fleming',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '20714.7067340702',
#   'room_number': '234',
#   'admission_type': 'Urgent',
#   'discharge_date': '2021-07-21',
#   'medication': 'Lipitor',
#   'test_results': 'Inconclusive'},
#  {'name': 'AnNE lam',
#   'age': '85',
#   'gender': 'Male',
#   'blood_type': 'O+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2024-01-19',
#   'doctor': 'Paul Ruiz',
#   'hospital': 'Christian-Hall',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '34510.884904131046',
#   'room_number': '292',
#   'admission_type': 'Elective',
#   'discharge_date': '2024-02-05',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'jEnnifeR GomEz',
#   'age': '45',
#   'gender': 'Male',
#   'blood_type': 'O-',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2020-12-15',
#   'doctor': 'Robert Palmer',
#   'hospital': 'LLC Cabrera',
#   'insurance_provider': 'Blue Cross',
#   'billing_amount': '42200.51465496005',
#   'room_number': '115',
#   'admission_type': 'Elective',
#   'discharge_date': '2021-01-13',
#   'medication': 'Lipitor',
#   'test_results': 'Inconclusive'},
#  {'name': 'daVId CuRTIs',
#   'age': '22',
#   'gender': 'Female',
#   'blood_type': 'B+',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2021-05-14',
#   'doctor': 'Lisa Grimes',
#   'hospital': 'Hernandez and Delacruz, Kramer',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '24451.289481048025',
#   'room_number': '413',
#   'admission_type': 'Emergency',
#   'discharge_date': '2021-05-28',
#   'medication': 'Paracetamol',
#   'test_results': 'Abnormal'},
#  {'name': 'joSHUa JOHnsON',
#   'age': '18',
#   'gender': 'Male',
#   'blood_type': 'B+',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2021-07-10',
#   'doctor': 'Ronald Russell',
#   'hospital': 'Cervantes-Herrera',
#   'insurance_provider': 'UnitedHealthcare',
#   'billing_amount': '30289.70490881633',
#   'room_number': '165',
#   'admission_type': 'Emergency',
#   'discharge_date': '2021-07-12',
#   'medication': 'Paracetamol',
#   'test_results': 'Normal'},
#  {'name': 'jEReMy bOwen',
#   'age': '60',
#   'gender': 'Male',
#   'blood_type': 'B-',
#   'medical_condition': 'Diabetes',
#   'date_of_admission': '2020-07-25',
#   'doctor': 'Tracey Smith',
#   'hospital': 'Garrison-Mcfarland',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '35317.49303975063',
#   'room_number': '431',
#   'admission_type': 'Urgent',
#   'discharge_date': '2020-07-29',
#   'medication': 'Lipitor',
#   'test_results': 'Normal'},
#  {'name': 'denNIs cLarkE',
#   'age': '22',
#   'gender': 'Female',
#   'blood_type': 'AB+',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2019-09-17',
#   'doctor': 'Mark Baker',
#   'hospital': 'Warren-Brown',
#   'insurance_provider': 'Cigna',
#   'billing_amount': '8033.61165471249',
#   'room_number': '293',
#   'admission_type': 'Elective',
#   'discharge_date': '2019-10-01',
#   'medication': 'Lipitor',
#   'test_results': 'Inconclusive'},
#  {'name': 'jeNNiFER spEnCe',
#   'age': '65',
#   'gender': 'Female',
#   'blood_type': 'A+',
#   'medical_condition': 'Obesity',
#   'date_of_admission': '2019-05-14',
#   'doctor': 'Austin Perry',
#   'hospital': 'Ruiz Group',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '7391.534745436652',
#   'room_number': '270',
#   'admission_type': 'Elective',
#   'discharge_date': '2019-05-20',
#   'medication': 'Aspirin',
#   'test_results': 'Inconclusive'},
#  {'name': 'biLlY fITZGERALd',
#   'age': '73',
#   'gender': 'Female',
#   'blood_type': 'B+',
#   'medical_condition': 'Asthma',
#   'date_of_admission': '2020-05-31',
#   'doctor': 'Dr. Mackenzie Bell',
#   'hospital': 'Anderson-Brown',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '35945.884474187944',
#   'room_number': '146',
#   'admission_type': 'Emergency',
#   'discharge_date': '2020-06-28',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'krisTEN JamES',
#   'age': '82',
#   'gender': 'Female',
#   'blood_type': 'AB+',
#   'medical_condition': 'Hypertension',
#   'date_of_admission': '2020-03-27',
#   'doctor': 'Kimberly Calhoun',
#   'hospital': 'Hull Sons and',
#   'insurance_provider': 'Medicare',
#   'billing_amount': '10780.742007834762',
#   'room_number': '472',
#   'admission_type': 'Emergency',
#   'discharge_date': '2020-04-04',
#   'medication': 'Ibuprofen',
#   'test_results': 'Inconclusive'},
#  {'name': 'cAiTLIN bEndEr',
#   'age': '32',
#   'gender': 'Female',
#   'blood_type': 'O-',
#   'medical_condition': 'Arthritis',
#   'date_of_admission': '2019-12-23',
#   'doctor': 'Timothy Aguilar',
#   'hospital': 'Oliver Mcdonald, and Johnson',
#   'insurance_provider': 'Aetna',
#   'billing_amount': '28743.00383788984',
#   'room_number': '493',
#   'admission_type': 'Elective',
#   'discharge_date': '2019-12-30',
#   'medication': 'Penicillin',
#   'test_results': 'Normal'}]

# %%
health_df.columns
# Out:
# Index(['name', 'age', 'gender', 'blood_type', 'medical_condition',
#        'date_of_admission', 'doctor', 'hospital', 'insurance_provider',
#        'billing_amount', 'room_number', 'admission_type', 'discharge_date',
#        'medication', 'test_results'],
#       dtype='object')

# %%
index = minsearch.Index(
    text_fields=['age', 'gender', 'blood_type', 'medical_condition',
       'date_of_admission', 'doctor', 'hospital', 'insurance_provider',
       'billing_amount', 'room_number', 'admission_type', 'discharge_date',
       'medication', 'test_results'],
    keyword_fields=[]
)

# %%
import minsearch

# %%
index.fit(documents)

# %%
def search(query):
    boost = {}

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=5
    )

    return results

# %%
prompt_template = """
You're a heatlcare data analyser. Answer the QUESTION based on the CONTEXT from our exercises database.
Use only the facts from the CONTEXT when answering the QUESTION.

QUESTION: {question}

CONTEXT:
{context}
""".strip()

entry_template = """
age: {age}
gender: {gender}
blood_type: {blood_type}
medical_condition: {medical_condition}
insurance_provider: {insurance_provider}
billing_amount: {billing_amount}
test_results: {test_results}
""".strip()

def build_prompt(query, search):
    context = ""
    
    for doc in search:
        context = context + entry_template.format(**doc) + "\n\n"

    prompt = prompt_template.format(question=query, context=context).strip()
    return prompt

# %%
def llm(prompt):
    response = client.chat.completions.create(
        model='phi3',
        messages=[{"role": "user", "content": prompt}]
    )
    
    return response.choices[0].message.content

# %%
def rag(query):
    search_results = search(query)
    prompt = build_prompt(query, search_results)
    answer = llm(prompt)
    return answer

# %%
from openai import OpenAI

client = OpenAI(
    base_url='http://localhost:11434/v1/',
    api_key='ollama',
)

# %%
query = 'medical_condition of Normal test_results'

# %%
rag(query)
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 rag(query)
#
# Cell In[39], line 4, in rag(query)
#       2 search_results = search(query)
#       3 prompt = build_prompt(query, search_results)
# ----> 4 answer = llm(prompt)
#       5 return answer
#
# Cell In[38], line 2, in llm(prompt)
#       1 def llm(prompt):
# ----> 2     response = client.chat.completions.create(
#       3         model='phi3',
#       4         messages=[{"role": "user", "content": prompt}]
#       5     )
#       7     return response.choices[0].message.content
#
# File ~/.local/share/virtualenvs/rag-project-zXqblLGR/lib/python3.12/site-packages/openai/_utils/_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/rag-project-zXqblLGR/lib/python3.12/site-packages/openai/resources/chat/completions.py:668, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     633 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     634 def create(
#     635     self,
#    (...)
#     665     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     666 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     667     validate_response_format(response_format)
# --> 668     return self._post(
#     669         "/chat/completions",
#     670         body=maybe_transform(
#     671             {
#     672                 "messages": messages,
#     673                 "model": model,
#     674                 "frequency_penalty": frequency_penalty,
#     675                 "function_call": function_call,
#     676                 "functions": functions,
#     677                 "logit_bias": logit_bias,
#     678                 "logprobs": logprobs,
#     679                 "max_tokens": max_tokens,
#     680                 "n": n,
#     681                 "parallel_tool_calls": parallel_tool_calls,
#     682                 "presence_penalty": presence_penalty,
#     683                 "response_format": response_format,
#     684                 "seed": seed,
#     685                 "service_tier": service_tier,
#     686                 "stop": stop,
#     687                 "stream": stream,
#     688                 "stream_options": stream_options,
#     689                 "temperature": temperature,
#     690                 "tool_choice": tool_choice,
#     691                 "tools": tools,
#     692                 "top_logprobs": top_logprobs,
#     693                 "top_p": top_p,
#     694                 "user": user,
#     695             },
#     696             completion_create_params.CompletionCreateParams,
#     697         ),
#     698         options=make_request_options(
#     699             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     700         ),
#     701         cast_to=ChatCompletion,
#     702         stream=stream or False,
#     703         stream_cls=Stream[ChatCompletionChunk],
#     704     )
#
# File ~/.local/share/virtualenvs/rag-project-zXqblLGR/lib/python3.12/site-packages/openai/_base_client.py:1260, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1246 def post(
#    1247     self,
#    1248     path: str,
#    (...)
#    1255     stream_cls: type[_StreamT] | None = None,
#    1256 ) -> ResponseT | _StreamT:
#    1257     opts = FinalRequestOptions.construct(
#    1258         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1259     )
# -> 1260     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/share/virtualenvs/rag-project-zXqblLGR/lib/python3.12/site-packages/openai/_base_client.py:937, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     928 def request(
#     929     self,
#     930     cast_to: Type[ResponseT],
#    (...)
#     935     stream_cls: type[_StreamT] | None = None,
#     936 ) -> ResponseT | _StreamT:
# --> 937     return self._request(
#     938         cast_to=cast_to,
#     939         options=options,
#     940         stream=stream,
#     941         stream_cls=stream_cls,
#     942         remaining_retries=remaining_retries,
#     943     )
#
# File ~/.local/share/virtualenvs/rag-project-zXqblLGR/lib/python3.12/site-packages/openai/_base_client.py:1026, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1024 if retries > 0 and self._should_retry(err.response):
#    1025     err.response.close()
# -> 1026     return self._retry_request(
#    1027         input_options,
#    1028         cast_to,
#    1029         retries,
#    1030         err.response.headers,
#    1031         stream=stream,
#    1032         stream_cls=stream_cls,
#    1033     )
#    1035 # If the response is streamed then we need to explicitly read the response
#    1036 # to completion before attempting to access the response text.
#    1037 if not err.response.is_closed:
#
# File ~/.local/share/virtualenvs/rag-project-zXqblLGR/lib/python3.12/site-packages/openai/_base_client.py:1075, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1071 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1072 # different thread if necessary.
#    1073 time.sleep(timeout)
# -> 1075 return self._request(
#    1076     options=options,
#    1077     cast_to=cast_to,
#    1078     remaining_retries=remaining,
#    1079     stream=stream,
#    1080     stream_cls=stream_cls,
#    1081 )
#
# File ~/.local/share/virtualenvs/rag-project-zXqblLGR/lib/python3.12/site-packages/openai/_base_client.py:1026, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1024 if retries > 0 and self._should_retry(err.response):
#    1025     err.response.close()
# -> 1026     return self._retry_request(
#    1027         input_options,
#    1028         cast_to,
#    1029         retries,
#    1030         err.response.headers,
#    1031         stream=stream,
#    1032         stream_cls=stream_cls,
#    1033     )
#    1035 # If the response is streamed then we need to explicitly read the response
#    1036 # to completion before attempting to access the response text.
#    1037 if not err.response.is_closed:
#
# File ~/.local/share/virtualenvs/rag-project-zXqblLGR/lib/python3.12/site-packages/openai/_base_client.py:1075, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1071 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1072 # different thread if necessary.
#    1073 time.sleep(timeout)
# -> 1075 return self._request(
#    1076     options=options,
#    1077     cast_to=cast_to,
#    1078     remaining_retries=remaining,
#    1079     stream=stream,
#    1080     stream_cls=stream_cls,
#    1081 )
#
# File ~/.local/share/virtualenvs/rag-project-zXqblLGR/lib/python3.12/site-packages/openai/_base_client.py:1041, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1038         err.response.read()
#    1040     log.debug("Re-raising status error")
# -> 1041     raise self._make_status_error_from_response(err.response) from None
#    1043 return self._process_response(
#    1044     cast_to=cast_to,
#    1045     options=options,
#    (...)
#    1049     retries_taken=options.get_max_retries(self.max_retries) - retries,
#    1050 )
#
# InternalServerError: Error code: 500 - {'error': {'message': 'model requires more system memory (5.6 GiB) than is available (1.1 GiB)', 'type': 'api_error', 'param': None, 'code': None}}
